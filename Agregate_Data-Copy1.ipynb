# %% [markdown]
# Keywords Climate Change, Precipitation(rainfall), Heat, Extrene Events/weather

# %%
import os

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
os.chdir('/home/central/majes1ce/notebooks/Climate Project/keycountsummary')
path = '/home/central/majes1ce/notebooks/Climate Project/keycountsummary'
files_and_dirs = os.listdir(path)

# %%
import glob

file_paths = glob.glob("/home/central/majes1ce/notebooks/Climate Project/keycountsummary/*.csv")

# %%
#Python class
class wordcounter:
    climate = 0
    precip = 0
    heat = 0
    events = 0

# %%
from pathlib import Path
import csv

climate_keywords = {'climate', 'Climate', 'CLIMATE'}
precip_keywords = {'rain', 'rains', 'Rain', 'Rains', 'RAIN', 'RAINS', 'rainfall', 'Rainfall', 'RAINFALL', 'stormwater', 'Stormwater', 'STORMWATER'}
heat_keywords = {'heat', 'Heat', 'HEAT'}
events_keywords = {'weather', 'Weather', 'WEATHER', 'severe', 'Severe', 'SEVERE'}

results = {}

for file_path in file_paths:
    filename = file_path.split("/")[-1]
    parts = filename.split("_",3)
    location = parts[0] + "_" + parts[1] #Shortens file name into county and city only
    
    results[location] = wordcounter()
    with open (file_path) as csvfile:
        df = csv.reader(csvfile)
        for row in df:
            if row[0] in climate_keywords:
                results[location].climate += int(row[1])
            if row[0] in precip_keywords:
                results[location].precip += int(row[1])
            if row[0] in events_keywords:
                results[location].events += int(row[1])
            if row[0] in heat_keywords:
                results[location].heat += int(row[1])

results = {key: value for key, value in sorted(results.items())}
                
print (f'Location,Climate Count,Precip Count,Events Count,Heat Count')  
for location, count in results.items():
    print(f'{location},{count.climate},{count.precip},{count.events},{count.heat}')
# Out:
# Location,Climate Count,Precip Count,Events Count,Heat Count
# Alcona_Alcona,92,66,147,296
# Alcona_AlconaCaledoniaHawesTownships,13,43,7,24
# Alcona_CurtisTownship,13,41,7,15
# Alcona_GreenbushTownship,13,51,17,12
# Alcona_MikadoTownship,16,61,15,12
# Alcona_MitchellTownship,8,43,9,6
# Alcona_VillageofLincoln,16,18,6,9
# Alger_AlgerCounty,16,149,125,58
# Alger_AuTrainTownship,19,609,12,26
# Alger_BurtTownship,17,27,2,15
# Alger_GrandIslandTownship,0,14,0,9
# Alger_Munising,12,14,2,3
# Alger_MunisingTownship,19,65,7,23
# Alger_OnotaTownship,11,105,9,9
# Alger_RockRiverTownship,0,17,0,18
# Allegan_AlleganCity,6,28,0,12
# Allegan_AlleganCounty,0,2,0,15
# Allegan_AlleganTwp,0,21,4,10
# Allegan_CityofVillageofDouglas,0,2,1,0
# Allegan_ClydeTwp,8,20,14,3
# Allegan_DorrTwp,3,105,4,0
# Allegan_Fennville,0,18,0,12
# Allegan_FillmoreTwp,3,46,6,51
# Allegan_GangesTwp,57,13,2,8
# Allegan_GunPlainCharterTwp,13,22,4,0
# Allegan_Holland,6,0,0,0
# Allegan_HopkinsTwp,11,28,1,0
# Allegan_LaketownTwp,0,79,1,8
# Allegan_LeeTwp,0,26,0,0
# Allegan_LeightonTwp,0,41,2,3
# Allegan_MartinTwp,0,0,0,0
# Allegan_MontereyTwp,0,47,6,51
# Allegan_Otsego,0,7,0,0
# Allegan_Plainwell,6,21,0,5
# Allegan_SalemTwp,8,29,6,0
# Allegan_SouthHaven,0,14,2,6
# Allegan_TriCommunity,19,87,14,14
# Allegan_TrowbridgeTwp,0,37,1,25
# Allegan_ValleyTwp,0,33,1,45
# Allegan_Wayland,9,50,14,53
# Alpena_Alpena,33,47,10,67
# Alpena_AlpenaCounty,90,124,146,269
# Alpena_AlpenaTwp,37,57,6,6
# Alpena_Hillman,19,37,3,12
# Alpena_Joint,24,112,15,70
# Alpena_LongRapidsTwp,0,12,1,21
# Alpena_SanbornTwp,0,70,3,50
# Alpena_WellingtonTwp,0,155,8,39
# Antrim_AntrimCounty,235,45,132,186
# Antrim_BanksTwp,15,20,8,0
# Antrim_Bellaire,8,24,3,5
# Antrim_CentralLake,13,11,4,0
# Antrim_ElkRapidsVElkRapidsTwp,0,10,0,0
# Antrim_Ellsworth,13,11,7,3
# Antrim_ForestHomeTwp,15,23,8,3
# Antrim_HelenaTwp,0,0,0,0
# Antrim_KearneyTwp,0,10,1,0
# Antrim_MancelonaVTwp,5,16,3,0
# Antrim_TorchLake,0,32,0,30
# Arenac_ArenacCounty,39,251,381,115
# Arenac_DeepRiverTwp,0,56,4,65
# Arenac_LincolnTwp,3,36,0,24
# Arenac_MoffattTwp,6,36,1,0
# Arenac_SimsTwp,0,50,5,66
# Arenac_StandishTwp,3,20,6,3
# Baraga_ArvonTwp,45,20,3,14
# Baraga_Baraga,5,4,3,0
# Baraga_BaragaCOunty,173,147,153,175
# Baraga_BaragaTwp,401,60,59,41
# Baraga_CovingtonTwp,0,16,4,12
# Baraga_L'anse,85,96,11,93
# Baraga_L'anseTwp,35,59,4,6
# Barrien_Stevensville,3,34,5,3
# Barry_BarryCounty,3,109,177,225
# Barry_Hastings,6,21,2,9
# Barry_Middleville,0,43,1,28
# Barry_Nashville,0,0,0,0
# Barry_RutlandTwp,24,34,5,43
# Barry_ThornappleTwp,0,77,2,51
# Barry_YankeeSpringsTwp,0,36,0,3
# Bay_Auburn,0,6,3,0
# Bay_BayCity,59,86,9,62
# Bay_BayCounty,59,318,241,223
# Bay_BeaverTwp,0,48,0,21
# Bay_Essexville,0,16,3,49
# Bay_HamptonTwp,8,12,0,3
# Bay_Midland,9,47,3,11
# Benzie_AlmiraTwp,13,22,4,10
# Benzie_BenzieCounty,226,170,159,270
# Benzie_Benzonia,3,44,4,3
# Benzie_Benzonia-PlatteTwp,0,1,0,3
# Benzie_Beulah,0,30,0,14
# Benzie_BlaineTwp,0,0,0,0
# Benzie_Elberta,0,30,3,0
# Benzie_Frankfort,23,63,5,18
# Benzie_GilmoreTwp,3,9,2,12
# Benzie_InlandTwp,0,17,0,0
# Benzie_JoyfieldTwp,0,0,0,3
# Benzie_LakeAnn,0,27,0,6
# Benzie_LakeTwp,0,1,0,0
# Berrien_BainbridgeTwp,3,5,0,0
# Berrien_Baroda,3,6,0,0
# Berrien_BerrienCounty,111,277,575,200
# Berrien_BertrandTwp,0,15,0,0
# Berrien_Bridgman,581,93,38,214
# Berrien_Buchanan,47,25,4,29
# Berrien_ColomaTwp,0,11,0,0
# Berrien_GalienTwp,0,20,1,3
# Berrien_GrandBeach,0,13,3,3
# Berrien_HagarTwp,6,10,0,0
# Berrien_LakeCharterTwp,24,15,2,3
# Berrien_NewBuffalo,0,8,0,3
# Berrien_Niles,25,43,1,51
# Berrien_NilesTwp,3,48,0,3
# Berrien_OronokoTwp,0,27,5,41
# Berrien_PipestoneTwp,0,39,0,0
# Berrien_Shoreham,0,4,0,0
# Berrien_St. JosephTwp,9,17,0,0
# Berrien_St.Joseph,182,40,25,231
# Berrien_ThreeOaks,9,24,1,30
# Berrien_Watervliet,3,5,1,0
# Berrien_WatervlietTwp,0,3,0,0
# Berrien_WeesawTwp,3,19,0,0
# Branch_AlganseeTwp,0,26,2,0
# Branch_BranchCounty,80,278,389,391
# Branch_ButlerTwp,0,24,1,0
# Branch_Coldwater,0,8,1,15
# Branch_ColdwaterTwp,3,18,1,0
# Branch_GirardTwp,0,65,5,54
# Branch_KinderhookTwp,0,25,2,38
# Branch_MattesonTwp,0,56,11,29
# Branch_OvidTwp,0,26,0,0
# Branch_Quincy,32,34,6,9
# Calhoun_Albion,0,28,4,12
# Calhoun_AlbionTwp,0,6,0,42
# Calhoun_BattleCreek,23,44,1,9
# Calhoun_BedfordTwp,6,33,1,6
# Calhoun_CalhounCoMulti,249,99,221,223
# Calhoun_ClarendonTwp,0,21,3,6
# Calhoun_ConvisTwp,3,39,3,0
# Calhoun_FredoniaTwp,0,16,0,3
# Calhoun_Homer,0,6,0,13
# Calhoun_LeeTwp,0,38,1,54
# Calhoun_LeroyTwp,0,13,6,3
# Calhoun_MarengoTwp,0,60,4,6
# Calhoun_MarshallTwp,0,19,0,0
# Calhoun_NewtonTwp,0,26,1,32
# Calhoun_PennfieldTwp,6,91,3,36
# Calhoun_SheridanTwp,0,64,2,48
# Calhoun_SpringfieldTwp,0,73,1,33
# Cass_CalvinTwp,3,20,5,54
# Cass_CassCounty,62,281,204,39
# Cass_Cassopolis,0,10,0,0
# Cass_JeffersonTwp,3,75,4,100
# Cass_LaGrangeTwp,3,67,6,35
# Cass_Marcellus,0,14,0,3
# Cass_MasonTwp,0,7,0,0
# Cass_MiltonTwp,0,50,0,45
# Cass_OntwaTwp,25,25,6,3
# Cass_PokagonTwp,3,67,4,76
# Cass_PorterTwp,13,10,0,0
# Cass_SilverCreekTwp,0,31,4,27
# Cass_VoliniaTwp,3,61,3,70
# Charlevoix_BayTwp,6,11,1,0
# Charlevoix_BeaverIsland,130,31,20,15
# Charlevoix_BoyneCity,26,43,4,3
# Charlevoix_BoyneValleyTwp,0,14,2,0
# Charlevoix_Charlevoix,28,56,9,38
# Charlevoix_CharlevoixCounty,239,68,189,200
# Charlevoix_CharlevoixTwp,0,6,0,0
# Charlevoix_EastJordan,3,80,3,14
# Charlevoix_EvangelineTwp,0,1,1,0
# Charlevoix_HayesTwp,0,10,2,0
# Charlevoix_HudsonTwp,0,22,1,0
# Charlevoix_MarionTwp,0,22,3,3
# Charlevoix_MelroseTwp,0,28,1,3
# Charlevoix_NorwoodTwp,3,6,0,0
# Charlevoix_PeaineTwp,0,40,0,45
# Charlevoix_SouthArmTwp,0,33,2,15
# Charlevoix_StJamesTwp,16,25,8,0
# Charlevoix_WilsonTwp,33,22,2,0
# Cheboygan_BurtTwp,8,8,4,0
# Cheboygan_Cheboygan,0,7,1,0
# Cheboygan_CheboyganCounty,25,73,5,0
# Cheboygan_MackinawCity,13,43,10,0
# Cheboygan_TuscaroraTwp,8,23,2,0
# Cheboygan_Wolverine,16,14,3,8
# Chippewa_BayMillsTwp,0,14,1,3
# Chippewa_ChippewaCounty,47,104,116,125
# Chippewa_DafterTwp,5,10,1,18
# Chippewa_DeTourTwpandVofDetour,0,6,3,0
# Chippewa_DeTourVillage,38,33,7,9
# Chippewa_DrummondIslandTwp,0,0,2,0
# Chippewa_KinrossTwp,0,75,3,38
# Chippewa_PickfordTwp,10,10,2,15
# Chippewa_RaberTwp,3,2,0,0
# Chippewa_RudyardTwp,0,25,0,18
# Chippewa_SaultSteMarie,0,8,4,12
# Chippewa_SooTwp,0,17,4,18
# Chippewa_SugarIslandTwp,0,5,4,3
# Chippewa_SuperiorTwp,0,41,1,33
# Chippewa_TroutLakeTwp,3,4,0,0
# Clare_Clare,3,13,0,9
# Clare_ClareCounty,36,235,254,195
# Clare_Farwell,20,49,4,15
# Clare_FreemanTwp,0,1,0,0
# Clare_GarfieldTwp,0,2,0,5
# Clare_HattonTwp,0,6,0,8
# Clare_HayesTwp,18,26,0,0
# Clare_LincolnTwp,23,39,0,0
# Clare_WinterfieldTwp,36,24,0,0
# Clinton_BengalTwp,0,24,2,0
# Clinton_ClintonCounty,11,29,0,3
# Clinton_DeWitt,3,39,0,36
# Clinton_DuplainTwp,0,4,0,0
# Clinton_Elsie,0,38,2,27
# Clinton_Fowler,0,31,3,30
# Clinton_GrandLedge,0,24,1,0
# Clinton_MapleRapids,6,54,6,42
# Clinton_Ovid,0,13,2,5
# Clinton_WatertownTwp,26,37,6,9
# Crawford_BeaverCreekTwp,21,37,9,12
# Crawford_CrawfordCounty,50,85,95,128
# Crawford_FredericTwp,8,10,3,6
# Crawford_GraylingTwp,21,37,10,0
# Crawford_MapleForestTwp,16,27,10,0
# Crawford_SouthBranchTwp,13,39,10,18
# Delta_DeltaCounty,19,136,140,58
# Delta_FordRiverTwp,0,31,0,9
# Delta_GardenCity,6,15,1,6
# Delta_GardenTwp,0,10,1,3
# Delta_Gladston,6,9,1,0
# Dickinson_BreenTwp,0,11,15,12
# Dickinson_BreitungTwp,37,23,2,3
# Dickinson_FelchTwp,6,12,1,9
# Dickinson_IronMountain,11,78,4,18
# Dickinson_Kingsford,14,31,5,23
# Dickinson_NorwayTwp,0,50,1,33
# Dickinson_SagolaTwp,31,14,4,3
# Eaton_BentonTwp,3,43,1,18
# Eaton_Charlotte,59,36,2,78
# Eaton_GrandLedge,0,24,1,0
# Eaton_HamlinTwp,3,57,4,9
# Eaton_Mulliken,0,27,3,53
# Eaton_OneidaTwp,6,17,2,0
# Eaton_Potterville,0,26,1,6
# Eaton_WindsorTwp,8,8,0,0
# Emmet_BearCreekTwp,20,61,8,0
# Emmet_Emmet,60,35,11,24
# Emmet_FriendshipTwp,70,43,3,5
# Emmet_LittleTraverseTwp,0,12,1,44
# Emmet_MackinawCity,13,43,10,0
# Emmet_Pellston,0,59,5,102
# Emmet_Petoskey,212,44,7,70
# Emmet_ResortTwp,85,32,12,14
# Emmet_WestTraverseTwp,3,46,3,3
# Genesee_Argentine,0,43,0,0
# Genesee_Burton,0,33,0,15
# Genesee_Clayton,0,23,0,0
# Genesee_Clio,0,26,0,21
# Genesee_Davidson,11,22,1,3
# Genesee_Fenton,6,35,5,9
# Genesee_Flint,3,2,0,0
# Genesee_FlintTwp,0,60,6,69
# Genesee_Flushing,3,12,0,6
# Genesee_FlushingTwp,6,22,72,3
# Genesee_GeneseeTwp,3,27,3,50
# Genesee_Goodrich,3,7,1,0
# Genesee_GrandBlanc,3,7,1,0
# Genesee_GrandBlancTwp,0,60,5,11
# Genesee_Linden,50,39,2,63
# Genesee_MtMorris,3,7,0,18
# Genesee_MtMorrisTwp,11,24,1,0
# Genesee_OtterLake,0,9,0,0
# Genesee_SwartzCreek,6,40,2,18
# Genesee_Vienna,0,49,2,41
# Gladwin_Beaverton,8,85,3,20
# Gladwin_Clement,0,3,1,3
# Gladwin_Gladwin,6,52,1,24
# Gladwin_GladwinCounty,168,324,237,235
# Gogebic_Bessemer,39,28,4,70
# Gogebic_BessemerTwp,9,139,7,107
# Gogebic_Erwin,0,8,0,0
# Gogebic_GogebicCounty,168,162,190,220
# Gogebic_Ironwood,19,24,1,24
# Gogebic_WakefieldTwp,25,10,9,19
# Gogebic_Watersmeet,0,6,0,0
# GrandTraverse_EastBay,96,34,5,8
# GrandTraverse_FifeLakeVillageandTownship,14,15,1,0
# GrandTraverse_Garfield,0,17,3,6
# GrandTraverse_GrandTraverseCounty,71,172,112,164
# GrandTraverse_Kingsley,0,4,0,5
# GrandTraverse_LongLake,26,45,3,6
# Gratiot_Ashley,0,25,0,12
# Gratiot_GratiotCounty,48,258,253,208
# Gratiot_Ithaca,0,1,0,0
# Gratiot_StLouis,0,4,0,12
# Hillsdale_CamdenTWP,0,38,4,24
# Hillsdale_Hillsdale,3,27,13,0
# Hillsdale_Jonesville,3,11,1,57
# Hillsdale_Litchfield,0,22,0,15
# Hillsdale_Reading,3,64,3,49
# Houghton_Hancock,46,4,7,15
# Houghton_Houghton,191,278,172,215
# Houghton_Laurium,117,33,10,70
# Houghton_PortageTwp,0,24,3,39
# Huron_Caseville,0,10,0,3
# Huron_Elkton,0,32,1,56
# Huron_Pigeon,0,13,1,35
# Huron_PortAustin,0,52,0,53
# Ingham_Dansville,6,2,1,3
# Ingham_DelhiTwp,0,25,0,20
# Ingham_Mason,0,45,8,3
# Ingham_MeridianTwp,36,12,1,3
# Ingham_Stockbridge,0,17,1,5
# Ingham_Williamston,3,8,8,63
# Ionia_Clarksville,0,14,0,0
# Ionia_Muir,0,5,1,6
# Ionia_Pewamo,0,6,0,0
# Ionia_Portland,8,21,8,6
# Ionia_Saranac,3,71,7,48
# Iosco_AuSableTwp,13,16,0,21
# Iosco_EastTawas,13,24,3,6
# Iosco_IoscoCounty,27,258,299,240
# Iosco_OscodaTwp,18,24,2,6
# Iosco_TawasCity,0,27,2,12
# Iron_Caspian,0,4,1,15
# Iron_CrystalFalls,3,21,2,27
# Iron_IronCounty,144,165,160,196
# Iron_IronRiver,22,24,4,0
# Isabella_IsabellaCounty,73,187,387,209
# Isabella_LakeIsabella,3,22,0,3
# Isabella_Shepherd,3,25,2,33
# Jackson_BlackmanTwp,0,20,0,6
# Jackson_Brooklyn,0,13,1,36
# Jackson_Concord,0,11,0,0
# Jackson_GrassLake,0,18,3,0
# Jackson_GrassLakeTwp,0,14,2,0
# Jackson_HanoverTwp,0,3,1,0
# Jackson_HenriettaTwp,0,19,2,9
# Jackson_Jackson,0,46,0,6
# Jackson_LibertyTwp,0,4,0,3
# Jackson_NapoleonTwp,0,8,1,3
# Jackson_Parma,0,9,0,0
# Jackson_ParmaTwp,0,37,1,0
# Jackson_PulaskiTwp,0,12,0,5
# Jackson_RivesTwp,0,13,0,3
# Jackson_SpringArborTwp,0,41,0,0
# Jackson_Springport,0,9,0,3
# Jackson_SummitTwp,0,30,5,0
# Kalamazoo_AugustaTwp,0,42,0,0
# Kalamazoo_ClimaxTwp,3,14,0,3
# Kalamazoo_ComstockTwp,9,0,0,0
# Kalamazoo_CooperTwp,3,21,1,0
# Kalamazoo_Galesburg,3,50,0,3
# Kalamazoo_KalamazooCounty,41,98,117,55
# Kalamazoo_KalamazooTwp,13,6,1,0
# Kalamazoo_Parchment,0,4,0,3
# Kalamazoo_SchoolcraftTwp,0,4,0,0
# Kalamazoo_Vicksburg,9,22,1,3
# Kalkaska_KalkaskaCounty,176,89,158,164
# Kent_Caledonia,6,13,0,0
# Kent_CaledoniaTwp,0,13,2,18
# Kent_CasnoviaTwp,6,11,1,3
# Kent_EastGrandRapids,0,5,0,0
# Kent_GainesTwp,0,12,0,6
# Kent_GrandRapidsTwp,0,17,1,16
# Kent_Grandville,0,14,0,15
# Kent_KentCity,0,3,0,0
# Kent_Kentwood,0,27,1,3
# Kent_LowellTwp,0,27,1,0
# Kent_Rockford,56,55,0,0
# Kent_Sparta,0,6,1,3
# Keweenaw_KeweenawCounty,174,129,127,170
# Lake_Baldwin,9,32,5,6
# Lake_Lake,227,279,665,382
# Lake_Luther,3,4,0,0
# Lapeer_Almont,0,44,0,6
# Lapeer_Dryden,0,16,1,3
# Lapeer_Lapeer,3,22,0,30
# Lapeer_NorthBranch,11,39,2,0
# Leelanau_ClevelandTwp,38,14,9,3
# Leelanau_ElmwoodTwp,26,23,3,0
# Leelanau_Empire,0,24,5,9
# Leelanau_GlenArborTwp,0,5,5,0
# Leelanau_Leelanau,3,59,0,9
# Leelanau_SuttonsBay,9,31,2,12
# Lenawee_Adrian,50,43,16,58
# Lenawee_Blissfield,29,28,1,8
# Lenawee_Clinton,0,21,0,0
# Lenawee_Hudson,0,2,1,3
# Lenawee_MadisonTwp,0,31,4,36
# Lenawee_Morenci,0,3,0,3
# Lenawee_Onsted,3,8,1,28
# Lenawee_RaisinTwp,0,11,0,9
# Lenawee_RollinTwp,0,7,0,6
# Lenawee_WoodstockTwp,0,1,0,6
# Livingston_Fowlerville,0,20,1,16
# Livingston_GenoaTwp,47,103,17,36
# Livingston_GreenOakTwp,0,23,2,0
# Livingston_Howell,3,10,1,16
# Livingston_Livingston,11,197,6,21
# Livingston_Pinckney,3,32,17,6
# Luce_Luce,55,71,172,104
# Luce_Newberry,6,28,1,12
# Mackinac_Mackinac,46,77,117,96
# Mackinac_MackinacIsland,29,26,8,15
# Mackinac_StIgnace,3,2,2,23
# Macomb_CenterLine,0,3,0,0
# Macomb_ChesterfieldTwp,15,36,14,20
# Macomb_ClintonTwp,9,65,1,68
# Macomb_Eastpointe,6,5,0,3
# Macomb_Fraser,3,16,0,15
# Macomb_HarrisonTwp,48,58,18,47
# Macomb_Macomb,27,391,135,173
# Macomb_MountClemens,6,11,1,6
# Macomb_NewBaltimore,0,23,0,6
# Macomb_NewHaven,6,11,1,3
# Macomb_Richmond,0,18,5,6
# Macomb_Romeo,6,8,5,3
# Macomb_Roseville,5,61,8,15
# Macomb_ShelbyTwp,3,28,0,0
# Macomb_StClairShores,108,46,8,35
# Macomb_Utica,0,12,0,3
# Macomb_WashingtonTwp,0,13,2,0
# Manistee_BearLake,0,100,4,53
# Manistee_Copemish,0,25,0,3
# Manistee_Manistee,236,198,275,290
# Marquette_Ishpeming,12,27,2,12
# Marquette_Marquette,125,84,76,56
# Marquette_Negaunee,12,27,3,13
# Mason_FreeSoil,0,21,1,30
# Mason_Ludington,32,36,11,20
# Mason_PereMarquette,70,27,14,12
# Mason_Scottville,6,2,1,0
# Mecosta_Barryton,10,8,0,6
# Mecosta_Mecosta,3,53,159,6
# Mecosta_Morley,0,3,0,0
# Menominee_MenomineeCounty,19,113,139,61
# Midland_Coleman,0,18,6,0
# Midland_Midland,9,47,3,11
# Midland_MidlandCounty,18,157,274,21
# Midland_MidlandTwp,0,5,0,0
# Midland_Sanford,0,9,5,6
# Missaukee_LakeCityArea,0,32,2,8
# Missaukee_McBain,15,28,0,18
# Missaukee_MissaukeeCounty,165,92,149,196
# Monroe_BerlinTwp,0,11,4,3
# Monroe_Carleton,6,22,0,3
# Monroe_Dundee,0,1,0,0
# Monroe_EstralBeach,0,12,4,12
# Monroe_FrenchtownTwp,95,38,15,12
# Monroe_LunaPier,0,21,4,80
# Monroe_Milan,3,72,5,54
# Monroe_Monroe,0,17,0,6
# Monroe_MonroeTwp,9,57,3,3
# Monroe_SouthRockwood,0,21,2,6
# Montcalm_CarsonCity,3,21,2,6
# Montcalm_Edmore,10,18,1,3
# Montcalm_Greenville,0,12,1,17
# Montcalm_HowardCityReynoldsTwp,0,58,0,9
# Montcalm_Lakeview,15,16,6,5
# Montcalm_PiersonTwp,0,0,0,6
# Montcalm_Stanton,0,17,0,25
# Montmorency_MontmorencyCounty,72,64,151,315
# Muskegon_Casnovia,3,46,4,30
# Muskegon_Fruitport,0,3,0,3
# Muskegon_LakewoodClub,6,26,2,27
# Muskegon_Montague,0,29,2,15
# Muskegon_Muskegon,0,26,2,13
# Muskegon_NortonShores,0,11,0,0
# Muskegon_Ravenna,0,1,0,0
# Muskegon_RooseveltPark,0,88,1,15
# Muskegon_Whitehall,18,32,2,27
# Newaygo_FremontCommunity,19,35,4,34
# Newaygo_Newaygo,0,14,0,3
# Newaygo_WhiteCloud,0,13,3,0
# Oakland_Berkley,19,36,1,8
# Oakland_BeverlyHills,3,41,3,18
# Oakland_BinghamFarms,28,34,7,18
# Oakland_CommerceTwp,14,34,16,39
# Oakland_Ferndale,439,189,22,155
# Oakland_Franklin,3,67,7,18
# Oakland_HazelPark,6,5,0,6
# Oakland_Holly,0,16,0,0
# Oakland_HuntingtonWoods,28,60,0,9
# Oakland_IndependenceTwp,3,25,1,73
# Oakland_KeegoHarbor,0,29,0,6
# Oakland_LakeOrion,0,0,0,0
# Oakland_Lathrup,25,36,10,21
# Oakland_Leonard,0,49,1,80
# Oakland_MilfordTwp,3,18,2,6
# Oakland_Northville,0,20,1,12
# Oakland_OakPark,6,6,5,9
# Oakland_OaklandTwp,15,44,1,12
# Oakland_OrchardLake,0,19,5,12
# Oakland_OrtonvilleBrandon,0,9,0,12
# Oakland_PleasantRidge,0,8,0,6
# Oakland_Rochester,17,61,10,26
# Oakland_RoyalOak,207,71,5,49
# Oakland_RoyalOakTwp,3,13,2,0
# Oakland_SouthLyon,6,35,2,9
# Oakland_Southfield,164,143,11,66
# Oakland_SpringfieldTwp,0,73,1,33
# Oakland_SylvanLake,25,39,15,44
# Oakland_WaterfordTwp,6,52,0,3
# Oakland_WhiteLakeTwp,3,41,2,3
# Oakland_Wixom,0,5,0,0
# Oakland_WolverineLake,0,26,3,12
# Oceana_Hart,0,4,0,3
# Oceana_NewEra,25,19,16,0
# Oceana_Oceana,19,48,11,6
# Oceana_PentwaterTwp,3,14,3,22
# Oceana_Shelby,6,94,2,6
# Ogemaw_Ogemaw,32,40,3,31
# Ogemaw_WestBranch,14,21,1,3
# Ontonagon_BerglandTwp,28,12,34,0
# Ontonagon_Ontonagon,150,159,162,199
# Osceola_Leroy,0,20,0,0
# Oscoda_Oscoda,66,76,177,334
# Oscoda_OscodaTwp,18,24,2,6
# Otsego_Otsego,40,27,3,25
# Otsego_Vanderbilt,61,25,23,24
# Ottawa_Coopersville,0,22,1,5
# Ottawa_Ferrysburg,0,13,0,0
# Ottawa_GeorgetownTwp,0,28,0,13
# Ottawa_GrandHaven,495,54,34,121
# Ottawa_GrandHavenTwp,0,0,0,0
# Ottawa_HollandTwp,0,2,0,0
# Ottawa_Hudsonville,0,12,0,51
# Ottawa_JamestownTwp,0,40,2,0
# Ottawa_SpringLakeTwp,0,0,0,3
# Ottawa_TallmadgeTwp,0,17,2,0
# Ottawa_Zeeland,0,4,1,0
# Ottawa_ZeelandTwp,0,32,0,3
# PresqueIsle_Onaway,11,33,5,12
# PresqueIsle_PresquIsleTwp,19,42,10,3
# PresqueIsle_PresqueIsleCounty-Posen,11,41,7,0
# PresqueIsle_RodgersCity,16,30,5,18
# Roscommon_Denton-RoscommonTwp,0,30,1,0
# Roscommon_HiggingsTwp,3,33,0,0
# Roscommon_LakeTwp,21,20,1,0
# Roscommon_Roscommon,13,28,7,45
# Saginaw_BuenaVista,0,36,0,9
# Saginaw_Chesaning,0,40,19,24
# Saginaw_Frankenmuth,8,99,8,12
# Saginaw_Saginaw,0,12,0,27
# Saginaw_StCharles,0,17,2,0
# Sanilac_Forestville,0,1,0,6
# Sanilac_Lexington,3,12,1,15
# Sanilac_Marlette,9,57,3,3
# Sanilac_Peck,3,20,0,15
# Sanilac_PortSanilac,0,5,1,6
# Sanilac_Sandusky,0,43,1,15
# Sanilac_SanilacCounty,0,41,2,26
# Schoolcraft_Manistique,9,19,2,3
# Shiawassee_Byron,0,29,0,15
# Shiawassee_Corunna,0,9,3,0
# Shiawassee_Ovid,0,13,2,5
# Shiawassee_Owosso,3,26,0,30
# Shiawassee_ShiawasseeCounty,0,4,2,0
# Shiawassee_Vernon,3,64,17,0
# StClair_Algonac,35,56,17,87
# StClair_FortGratiot,21,67,10,15
# StClair_Marine,10,54,5,20
# StClair_PortHuron,3,9,0,0
# StClair_Richmond,0,18,5,6
# StClair_StClairCounty,335,132,40,234
# StClair_Yale,0,47,2,87
# StJoseph_Centreville,0,2,1,0
# StJoseph_Colon,0,5,1,0
# StJoseph_Constantine,0,6,0,3
# StJoseph_WhitePigeon,3,5,0,9
# TribalDocuments_InterTribalCouncil,150,1,2,0
# TribalDocuments_KeweenawBayIndianCommunity,574,12,21,42
# TribalDocuments_LittleTraverseBayOdawa,74,2,1,131
# TribalDocuments_SaginawChippewa,73,250,200,208
# Tuscola_Caro,0,2,5,12
# Tuscola_CassCity,3,18,3,51
# Tuscola_GilfordTwp,37,9,2,15
# Tuscola_Mayville,3,22,0,12
# Tuscola_Millington,3,27,0,0
# Tuscola_Reese,0,17,4,0
# Tuscola_TuscolaCounty,21,115,5,18
# Tuscola_Vassar,6,15,5,0
# VanBuren_Decatur,0,3,0,0
# VanBuren_Hartford,9,11,1,9
# VanBuren_Lawrence,20,17,2,0
# VanBuren_PawPaw,6,30,1,27
# VanBuren_SouthHaven,0,14,2,6
# VanBuren_VanBurenCounty,15,35,1,0
# Washtenaw_AnnArbor,9,96,2,6
# Washtenaw_Augusta,0,27,0,0
# Washtenaw_BartonHills,6,18,0,3
# Washtenaw_Chelsea,3,20,2,25
# Washtenaw_Dexter,6,29,0,11
# Washtenaw_Manchester,3,30,0,0
# Washtenaw_Milan,0,42,6,21
# Washtenaw_Pittsfield,9,110,2,21
# Washtenaw_Saline,3,37,0,0
# Washtenaw_Superior,6,26,0,0
# Washtenaw_York,9,59,3,21
# Washtenaw_Ypsilanti,368,141,32,105
# Wayne_AllenPark,6,46,1,24
# Wayne_Ecorse,14,41,5,17
# Wayne_Gibraltar,3,15,2,3
# Wayne_GrossePointeFarms,28,69,9,93
# Wayne_GrossePointePark,0,23,3,12
# Wayne_Hamtramck,15,268,17,71
# Wayne_HarperWoods,39,102,6,9
# Wayne_Huron,0,19,0,0
# Wayne_Inkster,6,14,0,68
# Wayne_LincolnPark,21,89,4,15
# Wayne_Melvindale,6,18,0,0
# Wayne_Norhtville,0,30,0,0
# Wayne_Northville,0,36,2,27
# Wayne_Plymouth,0,0,7,3
# Wayne_Redford,206,21,7,70
# Wayne_RiverRouge,6,32,3,18
# Wayne_Riverview,29,33,3,0
# Wayne_Rockwood,3,47,0,3
# Wayne_Romulus,9,26,1,28
# Wayne_Wayne,0,22,0,12
# Wayne_Westland,8,16,4,3
# Wayne_Woodhaven,0,21,2,3
# Wayne_Wyandotte,0,13,0,17
# Wexford_Cadillac,11,20,2,6
# Wexford_Wexford,6,3,0,0
